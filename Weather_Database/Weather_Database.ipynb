# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import requests

# %%
# Create a new set of 2,000 random latitudes and longitudes.
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Get the nearest city using the citipy module.

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
#Perform an API call with the OpenWeatherMap.

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
#Retrieve the following information from the API call:
    #Latitude and longitude
    #Maximum temperature
    #Percent humidity
    #Percent cloudiness
    #Wind speed
    #Weather description (for example, clouds, fog, light rain, clear sky)


# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
        
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          #"Date": city_date,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | guadalupe y calvo
# Processing Record 2 of Set 1 | ribeira grande
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | nikolskoye
# Processing Record 5 of Set 1 | pangnirtung
# Processing Record 6 of Set 1 | bukama
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | cheremkhovo
# Processing Record 9 of Set 1 | tuatapere
# Processing Record 10 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 1 | ponta do sol
# Processing Record 12 of Set 1 | khatanga
# Processing Record 13 of Set 1 | saint-philippe
# Processing Record 14 of Set 1 | rozsypne
# Processing Record 15 of Set 1 | half moon bay
# Processing Record 16 of Set 1 | muisne
# Processing Record 17 of Set 1 | naze
# Processing Record 18 of Set 1 | victoria
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | cherskiy
# Processing Record 21 of Set 1 | codrington
# Processing Record 22 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 1 | carnarvon
# Processing Record 24 of Set 1 | kaohsiung
# Processing Record 25 of Set 1 | fortuna
# Processing Record 26 of Set 1 | iqaluit
# Processing Record 27 of Set 1 | qaanaaq
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | san cristobal
# Processing Record 30 of Set 1 | hobart
# Processing Record 31 of Set 1 | ondorhaan
# City not found. Skipping...
# Processing Record 32 of Set 1 | arlit
# Processing Record 33 of Set 1 | mukhen
# Processing Record 34 of Set 1 | hamilton
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | sao filipe
# Processing Record 37 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 1 | brae
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | zeya
# Processing Record 41 of Set 1 | longyearbyen
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | chokurdakh
# Processing Record 44 of Set 1 | lebu
# Processing Record 45 of Set 1 | denpasar
# Processing Record 46 of Set 1 | arraial do cabo
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | ballarat
# Processing Record 49 of Set 1 | yuancheng
# Processing Record 50 of Set 1 | requena
# Processing Record 1 of Set 2 | mayumba
# Processing Record 2 of Set 2 | hasaki
# Processing Record 3 of Set 2 | butembo
# Processing Record 4 of Set 2 | wanaka
# Processing Record 5 of Set 2 | burica
# City not found. Skipping...
# Processing Record 6 of Set 2 | kodiak
# Processing Record 7 of Set 2 | mehamn
# Processing Record 8 of Set 2 | manokwari
# Processing Record 9 of Set 2 | kavieng
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | valparaiso
# Processing Record 12 of Set 2 | ribeira brava
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | itoman
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | sukhumi
# Processing Record 18 of Set 2 | ligourion
# Processing Record 19 of Set 2 | port alfred
# Processing Record 20 of Set 2 | la palma
# Processing Record 21 of Set 2 | poum
# Processing Record 22 of Set 2 | sept-iles
# Processing Record 23 of Set 2 | narsaq
# Processing Record 24 of Set 2 | bafra
# Processing Record 25 of Set 2 | tamiahua
# Processing Record 26 of Set 2 | borogontsy
# Processing Record 27 of Set 2 | avarua
# Processing Record 28 of Set 2 | roma
# Processing Record 29 of Set 2 | amboasary
# Processing Record 30 of Set 2 | esperance
# Processing Record 31 of Set 2 | marsh harbour
# Processing Record 32 of Set 2 | port hedland
# Processing Record 33 of Set 2 | saint-georges
# Processing Record 34 of Set 2 | ust-nera
# Processing Record 35 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 2 | kloulklubed
# Processing Record 37 of Set 2 | nuevo ideal
# Processing Record 38 of Set 2 | dakar
# Processing Record 39 of Set 2 | sobolevo
# Processing Record 40 of Set 2 | akyab
# Processing Record 41 of Set 2 | lunenburg
# Processing Record 42 of Set 2 | kieta
# Processing Record 43 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 2 | mataura
# Processing Record 45 of Set 2 | ituni
# City not found. Skipping...
# Processing Record 46 of Set 2 | flagstaff
# Processing Record 47 of Set 2 | college
# Processing Record 48 of Set 2 | margate
# Processing Record 49 of Set 2 | hermanus
# Processing Record 50 of Set 2 | yeppoon
# Processing Record 1 of Set 3 | ilo
# Processing Record 2 of Set 3 | tasiilaq
# Processing Record 3 of Set 3 | hualmay
# Processing Record 4 of Set 3 | butaritari
# Processing Record 5 of Set 3 | lypova dolyna
# Processing Record 6 of Set 3 | kyren
# Processing Record 7 of Set 3 | touros
# Processing Record 8 of Set 3 | lorengau
# Processing Record 9 of Set 3 | kahului
# Processing Record 10 of Set 3 | santa rita
# Processing Record 11 of Set 3 | punta arenas
# Processing Record 12 of Set 3 | cape town
# Processing Record 13 of Set 3 | iraucuba
# Processing Record 14 of Set 3 | svetlyy
# Processing Record 15 of Set 3 | ixtapa
# Processing Record 16 of Set 3 | pevek
# Processing Record 17 of Set 3 | port hardy
# Processing Record 18 of Set 3 | dalmau
# Processing Record 19 of Set 3 | bozuyuk
# Processing Record 20 of Set 3 | asau
# Processing Record 21 of Set 3 | sao paulo de olivenca
# Processing Record 22 of Set 3 | carthage
# Processing Record 23 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 3 | makakilo city
# Processing Record 25 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 3 | castro
# Processing Record 28 of Set 3 | leh
# Processing Record 29 of Set 3 | fairbanks
# Processing Record 30 of Set 3 | grandview
# Processing Record 31 of Set 3 | port elizabeth
# Processing Record 32 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 3 | jubayl
# City not found. Skipping...
# Processing Record 34 of Set 3 | derac
# Processing Record 35 of Set 3 | tuktoyaktuk
# Processing Record 36 of Set 3 | dera ghazi khan
# Processing Record 37 of Set 3 | san vicente
# Processing Record 38 of Set 3 | vao
# Processing Record 39 of Set 3 | bay roberts
# Processing Record 40 of Set 3 | faanui
# Processing Record 41 of Set 3 | la carolina
# Processing Record 42 of Set 3 | new norfolk
# Processing Record 43 of Set 3 | east london
# Processing Record 44 of Set 3 | paamiut
# Processing Record 45 of Set 3 | bethel
# Processing Record 46 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 47 of Set 3 | prince rupert
# Processing Record 48 of Set 3 | bandarbeyla
# Processing Record 49 of Set 3 | agadez
# Processing Record 50 of Set 3 | paita
# Processing Record 1 of Set 4 | taltal
# Processing Record 2 of Set 4 | ostrovnoy
# Processing Record 3 of Set 4 | nabire
# Processing Record 4 of Set 4 | usila
# City not found. Skipping...
# Processing Record 5 of Set 4 | adrar
# Processing Record 6 of Set 4 | beneditinos
# Processing Record 7 of Set 4 | bambous virieux
# Processing Record 8 of Set 4 | torbay
# Processing Record 9 of Set 4 | namatanai
# Processing Record 10 of Set 4 | nanortalik
# Processing Record 11 of Set 4 | yulara
# Processing Record 12 of Set 4 | hithadhoo
# Processing Record 13 of Set 4 | lar
# Processing Record 14 of Set 4 | georgetown
# Processing Record 15 of Set 4 | naruto
# Processing Record 16 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 17 of Set 4 | upernavik
# Processing Record 18 of Set 4 | clyde river
# Processing Record 19 of Set 4 | korla
# Processing Record 20 of Set 4 | abu kamal
# Processing Record 21 of Set 4 | erenhot
# Processing Record 22 of Set 4 | biltine
# Processing Record 23 of Set 4 | labuhan
# Processing Record 24 of Set 4 | clearlake
# Processing Record 25 of Set 4 | vila velha
# Processing Record 26 of Set 4 | montepuez
# Processing Record 27 of Set 4 | lata
# Processing Record 28 of Set 4 | cascais
# Processing Record 29 of Set 4 | jining
# Processing Record 30 of Set 4 | sapouy
# Processing Record 31 of Set 4 | lagoa
# Processing Record 32 of Set 4 | skibbereen
# Processing Record 33 of Set 4 | zachagansk
# City not found. Skipping...
# Processing Record 34 of Set 4 | sola
# Processing Record 35 of Set 4 | socorro
# Processing Record 36 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 4 | wexford
# Processing Record 38 of Set 4 | lukulu
# Processing Record 39 of Set 4 | estelle
# Processing Record 40 of Set 4 | anzio
# Processing Record 41 of Set 4 | ucluelet
# Processing Record 42 of Set 4 | kirillov
# Processing Record 43 of Set 4 | kuusamo
# Processing Record 44 of Set 4 | nalut
# Processing Record 45 of Set 4 | los llanos de aridane
# Processing Record 46 of Set 4 | anito
# Processing Record 47 of Set 4 | keetmanshoop
# Processing Record 48 of Set 4 | camocim
# Processing Record 49 of Set 4 | grahamstown
# Processing Record 50 of Set 4 | evensk
# Processing Record 1 of Set 5 | pitea
# Processing Record 2 of Set 5 | bairiki
# Processing Record 3 of Set 5 | bredasdorp
# Processing Record 4 of Set 5 | linxia
# Processing Record 5 of Set 5 | winnemucca
# Processing Record 6 of Set 5 | shenjiamen
# Processing Record 7 of Set 5 | bogorodskoye
# Processing Record 8 of Set 5 | muyezerskiy
# Processing Record 9 of Set 5 | zhigansk
# Processing Record 10 of Set 5 | gizo
# Processing Record 11 of Set 5 | kuching
# Processing Record 12 of Set 5 | luwuk
# Processing Record 13 of Set 5 | harnosand
# Processing Record 14 of Set 5 | ajdabiya
# Processing Record 15 of Set 5 | nome
# Processing Record 16 of Set 5 | mercedes
# Processing Record 17 of Set 5 | san quintin
# Processing Record 18 of Set 5 | askiz
# Processing Record 19 of Set 5 | saravan
# Processing Record 20 of Set 5 | kismayo
# Processing Record 21 of Set 5 | calahorra
# Processing Record 22 of Set 5 | ilulissat
# Processing Record 23 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 24 of Set 5 | srednekolymsk
# Processing Record 25 of Set 5 | acapulco
# Processing Record 26 of Set 5 | saint-augustin
# Processing Record 27 of Set 5 | souillac
# Processing Record 28 of Set 5 | brigantine
# Processing Record 29 of Set 5 | chimbote
# Processing Record 30 of Set 5 | namibe
# Processing Record 31 of Set 5 | marigot
# Processing Record 32 of Set 5 | cidreira
# Processing Record 33 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 5 | palamos
# Processing Record 35 of Set 5 | dikson
# Processing Record 36 of Set 5 | atotonilco el grande
# Processing Record 37 of Set 5 | marmora
# Processing Record 38 of Set 5 | kaitangata
# Processing Record 39 of Set 5 | luderitz
# Processing Record 40 of Set 5 | el alto
# Processing Record 41 of Set 5 | pangai
# Processing Record 42 of Set 5 | salinopolis
# Processing Record 43 of Set 5 | saskylakh
# Processing Record 44 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 45 of Set 5 | grindavik
# Processing Record 46 of Set 5 | havoysund
# Processing Record 47 of Set 5 | thompson
# Processing Record 48 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 5 | meulaboh
# Processing Record 50 of Set 5 | husavik
# Processing Record 1 of Set 6 | krasnoselkup
# Processing Record 2 of Set 6 | crab hill
# City not found. Skipping...
# Processing Record 3 of Set 6 | port hawkesbury
# Processing Record 4 of Set 6 | kendari
# Processing Record 5 of Set 6 | longhua
# Processing Record 6 of Set 6 | lujiang
# Processing Record 7 of Set 6 | kununurra
# Processing Record 8 of Set 6 | tiksi
# Processing Record 9 of Set 6 | tawnat
# City not found. Skipping...
# Processing Record 10 of Set 6 | lubao
# Processing Record 11 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 12 of Set 6 | takahashi
# Processing Record 13 of Set 6 | kalmunai
# Processing Record 14 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 15 of Set 6 | qaqortoq
# Processing Record 16 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 6 | port blair
# Processing Record 18 of Set 6 | nowy dwor gdanski
# Processing Record 19 of Set 6 | zhanjiang
# Processing Record 20 of Set 6 | coquimbo
# Processing Record 21 of Set 6 | katsuura
# Processing Record 22 of Set 6 | buin
# Processing Record 23 of Set 6 | fort frances
# Processing Record 24 of Set 6 | poya
# Processing Record 25 of Set 6 | provideniya
# Processing Record 26 of Set 6 | mar del plata
# Processing Record 27 of Set 6 | praia
# Processing Record 28 of Set 6 | roxana
# Processing Record 29 of Set 6 | katangli
# Processing Record 30 of Set 6 | harrison
# Processing Record 31 of Set 6 | fort walton beach
# Processing Record 32 of Set 6 | harlow
# Processing Record 33 of Set 6 | avera
# Processing Record 34 of Set 6 | torit
# Processing Record 35 of Set 6 | bengkulu
# Processing Record 36 of Set 6 | anloga
# Processing Record 37 of Set 6 | griffith
# Processing Record 38 of Set 6 | norman wells
# Processing Record 39 of Set 6 | east wenatchee bench
# Processing Record 40 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 6 | roberval
# Processing Record 42 of Set 6 | mount pleasant
# Processing Record 43 of Set 6 | ambilobe
# Processing Record 44 of Set 6 | teloloapan
# Processing Record 45 of Set 6 | leningradskiy
# Processing Record 46 of Set 6 | bunbury
# Processing Record 47 of Set 6 | shashi
# Processing Record 48 of Set 6 | shibarghan
# City not found. Skipping...
# Processing Record 49 of Set 6 | klaksvik
# Processing Record 50 of Set 6 | kiunga
# Processing Record 1 of Set 7 | manjeshwar
# Processing Record 2 of Set 7 | mahebourg
# Processing Record 3 of Set 7 | bambari
# Processing Record 4 of Set 7 | jumla
# Processing Record 5 of Set 7 | suez
# Processing Record 6 of Set 7 | angoche
# Processing Record 7 of Set 7 | gagnoa
# Processing Record 8 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 9 of Set 7 | chuy
# Processing Record 10 of Set 7 | vredendal
# Processing Record 11 of Set 7 | santa ana
# Processing Record 12 of Set 7 | berdigestyakh
# Processing Record 13 of Set 7 | murud
# Processing Record 14 of Set 7 | barrow
# Processing Record 15 of Set 7 | rovnoye
# Processing Record 16 of Set 7 | henties bay
# Processing Record 17 of Set 7 | gwadar
# Processing Record 18 of Set 7 | marathon
# Processing Record 19 of Set 7 | gat
# Processing Record 20 of Set 7 | kielce
# Processing Record 21 of Set 7 | nantucket
# Processing Record 22 of Set 7 | nushki
# Processing Record 23 of Set 7 | awbari
# Processing Record 24 of Set 7 | geraldton
# Processing Record 25 of Set 7 | cabo san lucas
# Processing Record 26 of Set 7 | marawi
# Processing Record 27 of Set 7 | mponela
# Processing Record 28 of Set 7 | bilma
# Processing Record 29 of Set 7 | la ronge
# Processing Record 30 of Set 7 | noyabrsk
# Processing Record 31 of Set 7 | plettenberg bay
# Processing Record 32 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 7 | bulgan
# Processing Record 34 of Set 7 | saint-leu
# Processing Record 35 of Set 7 | edmundston
# Processing Record 36 of Set 7 | garden city
# Processing Record 37 of Set 7 | baruun-urt
# Processing Record 38 of Set 7 | coihueco
# Processing Record 39 of Set 7 | pringsewu
# Processing Record 40 of Set 7 | marsabit
# Processing Record 41 of Set 7 | buraydah
# Processing Record 42 of Set 7 | essau
# Processing Record 43 of Set 7 | ola
# Processing Record 44 of Set 7 | sisimiut
# Processing Record 45 of Set 7 | russkaya polyana
# Processing Record 46 of Set 7 | vrangel
# Processing Record 47 of Set 7 | samarai
# Processing Record 48 of Set 7 | crestview
# Processing Record 49 of Set 7 | le pradet
# Processing Record 50 of Set 7 | abu samrah
# Processing Record 1 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 8 | santa isabel
# Processing Record 3 of Set 8 | elizabeth city
# Processing Record 4 of Set 8 | susehri
# Processing Record 5 of Set 8 | camacha
# Processing Record 6 of Set 8 | nouadhibou
# Processing Record 7 of Set 8 | gobabis
# Processing Record 8 of Set 8 | ulladulla
# Processing Record 9 of Set 8 | sinnamary
# Processing Record 10 of Set 8 | vestmannaeyjar
# Processing Record 11 of Set 8 | tuy hoa
# Processing Record 12 of Set 8 | dunedin
# Processing Record 13 of Set 8 | presidencia roque saenz pena
# Processing Record 14 of Set 8 | belgrade
# Processing Record 15 of Set 8 | belmonte
# Processing Record 16 of Set 8 | vardo
# Processing Record 17 of Set 8 | shumerlya
# Processing Record 18 of Set 8 | chihuahua
# Processing Record 19 of Set 8 | zhezkazgan
# Processing Record 20 of Set 8 | padang
# Processing Record 21 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 8 | sibolga
# Processing Record 23 of Set 8 | pemba
# Processing Record 24 of Set 8 | madang
# Processing Record 25 of Set 8 | mogadishu
# Processing Record 26 of Set 8 | wanlaweyn
# Processing Record 27 of Set 8 | turtkul
# City not found. Skipping...
# Processing Record 28 of Set 8 | vila franca do campo
# Processing Record 29 of Set 8 | bowen
# Processing Record 30 of Set 8 | cabra
# Processing Record 31 of Set 8 | umea
# Processing Record 32 of Set 8 | morondava
# Processing Record 33 of Set 8 | tucuman
# Processing Record 34 of Set 8 | jatiroto
# Processing Record 35 of Set 8 | muravlenko
# Processing Record 36 of Set 8 | mirpur mathelo
# Processing Record 37 of Set 8 | podyuga
# Processing Record 38 of Set 8 | birao
# Processing Record 39 of Set 8 | hobyo
# Processing Record 40 of Set 8 | thinadhoo
# Processing Record 41 of Set 8 | aguada de pasajeros
# Processing Record 42 of Set 8 | sulangan
# Processing Record 43 of Set 8 | uhlove
# Processing Record 44 of Set 8 | santa luzia
# Processing Record 45 of Set 8 | kabwe
# Processing Record 46 of Set 8 | zyryanka
# Processing Record 47 of Set 8 | airai
# Processing Record 48 of Set 8 | saint george
# Processing Record 49 of Set 8 | anar darreh
# City not found. Skipping...
# Processing Record 50 of Set 8 | sao domingos
# Processing Record 1 of Set 9 | burnie
# Processing Record 2 of Set 9 | itaquyry
# Processing Record 3 of Set 9 | omboue
# Processing Record 4 of Set 9 | sindor
# Processing Record 5 of Set 9 | cardston
# Processing Record 6 of Set 9 | caravelas
# Processing Record 7 of Set 9 | karagaylinskiy
# Processing Record 8 of Set 9 | sao miguel do araguaia
# Processing Record 9 of Set 9 | tessalit
# Processing Record 10 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 11 of Set 9 | tezu
# Processing Record 12 of Set 9 | roald
# Processing Record 13 of Set 9 | novaya zaimka
# Processing Record 14 of Set 9 | yokadouma
# Processing Record 15 of Set 9 | rio das pedras
# Processing Record 16 of Set 9 | cap malheureux
# Processing Record 17 of Set 9 | araouane
# Processing Record 18 of Set 9 | nuuk
# Processing Record 19 of Set 9 | hambantota
# Processing Record 20 of Set 9 | resistencia
# Processing Record 21 of Set 9 | inuvik
# Processing Record 22 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 23 of Set 9 | chake chake
# Processing Record 24 of Set 9 | terney
# Processing Record 25 of Set 9 | ardistan
# City not found. Skipping...
# Processing Record 26 of Set 9 | shingu
# Processing Record 27 of Set 9 | saint-pierre
# Processing Record 28 of Set 9 | tabou
# Processing Record 29 of Set 9 | erdaojiang
# Processing Record 30 of Set 9 | sioux lookout
# Processing Record 31 of Set 9 | ahuimanu
# Processing Record 32 of Set 9 | abha
# Processing Record 33 of Set 9 | antalaha
# Processing Record 34 of Set 9 | bjerkvik
# Processing Record 35 of Set 9 | jasper
# Processing Record 36 of Set 9 | faya
# Processing Record 37 of Set 9 | guarapari
# Processing Record 38 of Set 9 | tautira
# Processing Record 39 of Set 9 | manati
# Processing Record 40 of Set 9 | maningrida
# Processing Record 41 of Set 9 | mopipi
# Processing Record 42 of Set 9 | lillesand
# Processing Record 43 of Set 9 | salihli
# Processing Record 44 of Set 9 | manyana
# Processing Record 45 of Set 9 | san patricio
# Processing Record 46 of Set 9 | soro
# Processing Record 47 of Set 9 | fomboni
# Processing Record 48 of Set 9 | simao
# Processing Record 49 of Set 9 | mount gambier
# Processing Record 50 of Set 9 | alice springs
# Processing Record 1 of Set 10 | teya
# Processing Record 2 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 3 of Set 10 | tongzi
# Processing Record 4 of Set 10 | dwarka
# Processing Record 5 of Set 10 | axim
# Processing Record 6 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 10 | huarmey
# Processing Record 8 of Set 10 | ballina
# Processing Record 9 of Set 10 | lompoc
# Processing Record 10 of Set 10 | chernyshkovskiy
# Processing Record 11 of Set 10 | chapais
# Processing Record 12 of Set 10 | camopi
# Processing Record 13 of Set 10 | nanakuli
# Processing Record 14 of Set 10 | kulhudhuffushi
# Processing Record 15 of Set 10 | stromness
# Processing Record 16 of Set 10 | parana
# Processing Record 17 of Set 10 | kingaroy
# Processing Record 18 of Set 10 | zaraza
# Processing Record 19 of Set 10 | saldanha
# Processing Record 20 of Set 10 | boat of garten
# Processing Record 21 of Set 10 | marienburg
# Processing Record 22 of Set 10 | khartoum
# Processing Record 23 of Set 10 | prince george
# Processing Record 24 of Set 10 | sorland
# Processing Record 25 of Set 10 | ostersund
# Processing Record 26 of Set 10 | nara
# Processing Record 27 of Set 10 | chiampo
# Processing Record 28 of Set 10 | natal
# Processing Record 29 of Set 10 | pacific grove
# Processing Record 30 of Set 10 | jalu
# Processing Record 31 of Set 10 | machilipatnam
# Processing Record 32 of Set 10 | taoudenni
# Processing Record 33 of Set 10 | dombarovskiy
# Processing Record 34 of Set 10 | havelock
# Processing Record 35 of Set 10 | boke
# Processing Record 36 of Set 10 | te anau
# Processing Record 37 of Set 10 | vanimo
# Processing Record 38 of Set 10 | banda aceh
# Processing Record 39 of Set 10 | boyolangu
# Processing Record 40 of Set 10 | palmer
# Processing Record 41 of Set 10 | sao joao da barra
# Processing Record 42 of Set 10 | moree
# Processing Record 43 of Set 10 | huangmei
# Processing Record 44 of Set 10 | alappuzha
# Processing Record 45 of Set 10 | dutse
# Processing Record 46 of Set 10 | mindelo
# Processing Record 47 of Set 10 | manzil jamil
# City not found. Skipping...
# Processing Record 48 of Set 10 | salalah
# Processing Record 49 of Set 10 | quatre cocos
# Processing Record 50 of Set 10 | pangkalanbuun
# Processing Record 1 of Set 11 | pisco
# Processing Record 2 of Set 11 | otjiwarongo
# Processing Record 3 of Set 11 | batouri
# Processing Record 4 of Set 11 | oriximina
# Processing Record 5 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 6 of Set 11 | sale
# Processing Record 7 of Set 11 | riyadh
# Processing Record 8 of Set 11 | alyangula
# Processing Record 9 of Set 11 | bathsheba
# Processing Record 10 of Set 11 | cockburn town
# Processing Record 11 of Set 11 | markova
# Processing Record 12 of Set 11 | puerto ayacucho
# Processing Record 13 of Set 11 | talnakh
# Processing Record 14 of Set 11 | lahat
# Processing Record 15 of Set 11 | bilibino
# Processing Record 16 of Set 11 | harper
# Processing Record 17 of Set 11 | xichang
# Processing Record 18 of Set 11 | iberia
# Processing Record 19 of Set 11 | bakchar
# Processing Record 20 of Set 11 | ciudad bolivar
# Processing Record 21 of Set 11 | alta floresta
# Processing Record 22 of Set 11 | raudeberg
# Processing Record 23 of Set 11 | quedlinburg
# Processing Record 24 of Set 11 | atar
# Processing Record 25 of Set 11 | uyuni
# Processing Record 26 of Set 11 | greenlaw
# Processing Record 27 of Set 11 | aswan
# Processing Record 28 of Set 11 | kumluca
# Processing Record 29 of Set 11 | tazovskiy
# Processing Record 30 of Set 11 | powell river
# Processing Record 31 of Set 11 | lesnoy
# Processing Record 32 of Set 11 | boende
# Processing Record 33 of Set 11 | dien bien
# City not found. Skipping...
# Processing Record 34 of Set 11 | olafsvik
# Processing Record 35 of Set 11 | colac
# Processing Record 36 of Set 11 | ishigaki
# Processing Record 37 of Set 11 | antofagasta
# Processing Record 38 of Set 11 | altagracia de orituco
# Processing Record 39 of Set 11 | cayenne
# Processing Record 40 of Set 11 | kljajicevo
# Processing Record 41 of Set 11 | strezhevoy
# Processing Record 42 of Set 11 | razole
# Processing Record 43 of Set 11 | lasa
# Processing Record 44 of Set 11 | haines junction
# Processing Record 45 of Set 11 | krasnoarmeysk
# Processing Record 46 of Set 11 | paz de ariporo
# City not found. Skipping...
# Processing Record 47 of Set 11 | corumba
# Processing Record 48 of Set 11 | dingle
# Processing Record 49 of Set 11 | damara
# Processing Record 50 of Set 11 | itarema
# Processing Record 1 of Set 12 | aylmer
# Processing Record 2 of Set 12 | sitka
# Processing Record 3 of Set 12 | kabalo
# Processing Record 4 of Set 12 | zhigalovo
# Processing Record 5 of Set 12 | arona
# Processing Record 6 of Set 12 | fort saint james
# Processing Record 7 of Set 12 | karratha
# Processing Record 8 of Set 12 | ferrol
# Processing Record 9 of Set 12 | boa vista
# Processing Record 10 of Set 12 | kawasaki
# Processing Record 11 of Set 12 | shuiji
# Processing Record 12 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 12 | missoula
# Processing Record 14 of Set 12 | trairi
# Processing Record 15 of Set 12 | tigil
# Processing Record 16 of Set 12 | praia da vitoria
# Processing Record 17 of Set 12 | laguna
# Processing Record 18 of Set 12 | basco
# Processing Record 19 of Set 12 | xuddur
# Processing Record 20 of Set 12 | khani
# Processing Record 21 of Set 12 | saint-louis
# Processing Record 22 of Set 12 | aksarka
# Processing Record 23 of Set 12 | bitung
# Processing Record 24 of Set 12 | gladstone
# Processing Record 25 of Set 12 | juneau
# Processing Record 26 of Set 12 | mirina
# City not found. Skipping...
# Processing Record 27 of Set 12 | san jeronimo
# Processing Record 28 of Set 12 | inhambane
# Processing Record 29 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 30 of Set 12 | am timan
# Processing Record 31 of Set 12 | kurilsk
# Processing Record 32 of Set 12 | mirabad
# Processing Record 33 of Set 12 | kindu
# Processing Record 34 of Set 12 | jamsa
# Processing Record 35 of Set 12 | humberto de campos
# Processing Record 36 of Set 12 | imeni poliny osipenko
# Processing Record 37 of Set 12 | ancud
# Processing Record 38 of Set 12 | pokhara
# Processing Record 39 of Set 12 | santa maria del oro
# Processing Record 40 of Set 12 | babstovo
# Processing Record 41 of Set 12 | mounana
# Processing Record 42 of Set 12 | usinsk
# Processing Record 43 of Set 12 | port-gentil
# Processing Record 44 of Set 12 | mamallapuram
# Processing Record 45 of Set 12 | broken hill
# Processing Record 46 of Set 12 | san jose
# Processing Record 47 of Set 12 | varzelandia
# Processing Record 48 of Set 12 | mutis
# Processing Record 49 of Set 12 | panguna
# Processing Record 50 of Set 12 | esmeralda
# Processing Record 1 of Set 13 | ayan
# Processing Record 2 of Set 13 | haslett
# Processing Record 3 of Set 13 | podstepki
# Processing Record 4 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 5 of Set 13 | kavaratti
# Processing Record 6 of Set 13 | yomitan
# City not found. Skipping...
# Processing Record 7 of Set 13 | urumqi
# Processing Record 8 of Set 13 | ossora
# Processing Record 9 of Set 13 | kyotera
# Processing Record 10 of Set 13 | zhangye
# Processing Record 11 of Set 13 | martapura
# Processing Record 12 of Set 13 | tostamaa
# City not found. Skipping...
# Processing Record 13 of Set 13 | marrakesh
# Processing Record 14 of Set 13 | flinders
# Processing Record 15 of Set 13 | assiniboia
# Processing Record 16 of Set 13 | tahoua
# Processing Record 17 of Set 13 | kalabo
# Processing Record 18 of Set 13 | synya
# Processing Record 19 of Set 13 | zhuhai
# Processing Record 20 of Set 13 | santiago del estero
# Processing Record 21 of Set 13 | amparafaravola
# Processing Record 22 of Set 13 | beringovskiy
# Processing Record 23 of Set 13 | peleduy
# Processing Record 24 of Set 13 | fujin
# Processing Record 25 of Set 13 | ampanihy
# Processing Record 26 of Set 13 | alofi
# Processing Record 27 of Set 13 | duluth
# Processing Record 28 of Set 13 | coihaique
# Processing Record 29 of Set 13 | eirunepe
# Processing Record 30 of Set 13 | gidam
# Processing Record 31 of Set 13 | tocopilla
# Processing Record 32 of Set 13 | liberia
# Processing Record 33 of Set 13 | waddan
# Processing Record 34 of Set 13 | comodoro rivadavia
# Processing Record 35 of Set 13 | ceres
# Processing Record 36 of Set 13 | carutapera
# Processing Record 37 of Set 13 | katobu
# Processing Record 38 of Set 13 | talaya
# Processing Record 39 of Set 13 | tromso
# Processing Record 40 of Set 13 | goure
# Processing Record 41 of Set 13 | liwale
# Processing Record 42 of Set 13 | rio gallegos
# Processing Record 43 of Set 13 | hofn
# Processing Record 44 of Set 13 | lashio
# Processing Record 45 of Set 13 | peniche
# Processing Record 46 of Set 13 | severo-kurilsk
# Processing Record 47 of Set 13 | bend
# Processing Record 48 of Set 13 | podlesnoye
# Processing Record 49 of Set 13 | katiola
# Processing Record 50 of Set 13 | sambava
# Processing Record 1 of Set 14 | tsentralnyy
# City not found. Skipping...
# Processing Record 2 of Set 14 | mariental
# Processing Record 3 of Set 14 | south sioux city
# Processing Record 4 of Set 14 | toftir
# City not found. Skipping...
# Processing Record 5 of Set 14 | batsfjord
# Processing Record 6 of Set 14 | pandan
# Processing Record 7 of Set 14 | bellegarde-sur-valserine
# Processing Record 8 of Set 14 | tiznit
# Processing Record 9 of Set 14 | tatarsk
# Processing Record 10 of Set 14 | calabozo
# Processing Record 11 of Set 14 | qui nhon
# Processing Record 12 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 13 of Set 14 | dragoman
# Processing Record 14 of Set 14 | sangar
# Processing Record 15 of Set 14 | road town
# Processing Record 16 of Set 14 | yining
# Processing Record 17 of Set 14 | sakakah
# Processing Record 18 of Set 14 | mount isa
# Processing Record 19 of Set 14 | marfino
# Processing Record 20 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 21 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 14 | buckingham
# Processing Record 23 of Set 14 | guiratinga
# Processing Record 24 of Set 14 | hay river
# Processing Record 25 of Set 14 | tongren
# Processing Record 26 of Set 14 | okaihau
# Processing Record 27 of Set 14 | joshimath
# Processing Record 28 of Set 14 | takoradi
# Processing Record 29 of Set 14 | ipswich
# Processing Record 30 of Set 14 | baghmara
# Processing Record 31 of Set 14 | champerico
# Processing Record 32 of Set 14 | tongliao
# Processing Record 33 of Set 14 | lincoln
# Processing Record 34 of Set 14 | bonavista
# Processing Record 35 of Set 14 | zaykovo
# Processing Record 36 of Set 14 | datong
# Processing Record 37 of Set 14 | harmanli
# Processing Record 38 of Set 14 | ponta delgada
# Processing Record 39 of Set 14 | simga
# Processing Record 40 of Set 14 | karachi
# Processing Record 41 of Set 14 | necochea
# Processing Record 42 of Set 14 | ilinskiy
# Processing Record 43 of Set 14 | galbshtadt
# Processing Record 44 of Set 14 | dareda
# Processing Record 45 of Set 14 | sur
# Processing Record 46 of Set 14 | isangel
# Processing Record 47 of Set 14 | dubai
# Processing Record 48 of Set 14 | cartagena
# Processing Record 49 of Set 14 | janakpur road
# City not found. Skipping...
# Processing Record 50 of Set 14 | narasannapeta
# Processing Record 1 of Set 15 | gilgit
# Processing Record 2 of Set 15 | homer
# Processing Record 3 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 4 of Set 15 | port macquarie
# Processing Record 5 of Set 15 | kiama
# Processing Record 6 of Set 15 | walvis bay
# Processing Record 7 of Set 15 | quzhou
# Processing Record 8 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 15 | beira
# Processing Record 10 of Set 15 | north bend
# Processing Record 11 of Set 15 | vostok
# Processing Record 12 of Set 15 | najran
# Processing Record 13 of Set 15 | singaraja
# Processing Record 14 of Set 15 | baghdad
# Processing Record 15 of Set 15 | aras
# Processing Record 16 of Set 15 | nacala
# Processing Record 17 of Set 15 | port lincoln
# Processing Record 18 of Set 15 | harwich
# Processing Record 19 of Set 15 | artyom
# Processing Record 20 of Set 15 | taicheng
# Processing Record 21 of Set 15 | lavrentiya
# Processing Record 22 of Set 15 | krasnyy chikoy
# Processing Record 23 of Set 15 | alamos
# Processing Record 24 of Set 15 | lakatoro
# Processing Record 25 of Set 15 | kisangani
# Processing Record 26 of Set 15 | khasan
# Processing Record 27 of Set 15 | kushmurun
# Processing Record 28 of Set 15 | kamennomostskiy
# Processing Record 29 of Set 15 | kisaran
# Processing Record 30 of Set 15 | corrales
# Processing Record 31 of Set 15 | hearst
# Processing Record 32 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 33 of Set 15 | teahupoo
# Processing Record 34 of Set 15 | buala
# Processing Record 35 of Set 15 | wagar
# Processing Record 36 of Set 15 | okhotsk
# Processing Record 37 of Set 15 | farafangana
# Processing Record 38 of Set 15 | kamenka
# Processing Record 39 of Set 15 | okrika
# Processing Record 40 of Set 15 | soe
# Processing Record 41 of Set 15 | davila
# Processing Record 42 of Set 15 | nishihara
# Processing Record 43 of Set 15 | andenes
# Processing Record 44 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 15 | mantua
# Processing Record 46 of Set 15 | tacoronte
# Processing Record 47 of Set 15 | sainte-ode
# Processing Record 48 of Set 15 | mahon
# Processing Record 49 of Set 15 | kemijarvi
# Processing Record 50 of Set 15 | makat
# Processing Record 1 of Set 16 | mocambique
# City not found. Skipping...
# Processing Record 2 of Set 16 | san juan
# Processing Record 3 of Set 16 | nokaneng
# Processing Record 4 of Set 16 | debno
# Processing Record 5 of Set 16 | utiroa
# City not found. Skipping...
# Processing Record 6 of Set 16 | bandundu
# Processing Record 7 of Set 16 | fengcheng
# Processing Record 8 of Set 16 | puri
# Processing Record 9 of Set 16 | mecca
# Processing Record 10 of Set 16 | hastings
# Processing Record 11 of Set 16 | wilson
# Processing Record 12 of Set 16 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 16 | kenai
# Processing Record 14 of Set 16 | vallenar
# Processing Record 15 of Set 16 | cabedelo
# Processing Record 16 of Set 16 | curaca
# Processing Record 17 of Set 16 | karoi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Add the data to a new DataFrame.
    #Before exporting your new DataFrame as a CSV file, take a moment to confirm that it looks similar to the image below:

#The new cities_data DataFrame summarizes the current weather description.

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0  Guadalupe Y Calvo      MX  26.1000 -106.9667     60.75        75
# 1     Ribeira Grande      PT  38.5167  -28.7000     72.00        83
# 2            Ushuaia      AR -54.8000  -68.3000     31.66        80
# 3         Nikolskoye      RU  59.7035   30.7861     76.89        90
# 4        Pangnirtung      CA  66.1451  -65.7125     51.71        61
#
#    Cloudiness  Wind Speed       Description
# 0         100        2.75   overcast clouds
# 1          40        9.22  scattered clouds
# 2          75        4.61     broken clouds
# 3         100        2.73   overcast clouds
# 4          71        8.10     broken clouds

# %%
#Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Databse.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8064/1393991140.py in <module>
#       3 output_data_file = "Weather_Database/WeatherPy_Databse.csv"
#       4 # Export the City_Data into a CSV.
# ----> 5 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3401             doublequote=doublequote,
#    3402             escapechar=escapechar,
# -> 3403             storage_options=storage_options,
#    3404         )
#    3405
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     232             errors=self.errors,
#     233             compression=self.compression,
# --> 234             storage_options=self.storage_options,
#     235         ) as handles:
#     236
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     645                 encoding=ioargs.encoding,
#     646                 errors=errors,
# --> 647                 newline="",
#     648             )
#     649         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Databse.csv'
