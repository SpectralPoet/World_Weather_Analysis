# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import requests

# %%
# Create a new set of 2,000 random latitudes and longitudes.
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Get the nearest city using the citipy module.

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 781

# %%
#Perform an API call with the OpenWeatherMap.

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
#Retrieve the following information from the API call:
    #Latitude and longitude
    #Maximum temperature
    #Percent humidity
    #Percent cloudiness
    #Wind speed
    #Weather description (for example, clouds, fog, light rain, clear sky)


# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
        
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          #"Date": city_date,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cabo san lucas
# Processing Record 2 of Set 1 | college
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | carnarvon
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | selikhino
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | narsaq
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | labuhan
# Processing Record 13 of Set 1 | acapulco
# Processing Record 14 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 1 | coahuayana
# Processing Record 16 of Set 1 | thai binh
# Processing Record 17 of Set 1 | chuy
# Processing Record 18 of Set 1 | montevideo
# Processing Record 19 of Set 1 | saint-philippe
# Processing Record 20 of Set 1 | banff
# Processing Record 21 of Set 1 | mahebourg
# Processing Record 22 of Set 1 | juneau
# Processing Record 23 of Set 1 | arraial do cabo
# Processing Record 24 of Set 1 | sao joao da barra
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | old orchard beach
# Processing Record 27 of Set 1 | kodiak
# Processing Record 28 of Set 1 | carballo
# Processing Record 29 of Set 1 | norman wells
# Processing Record 30 of Set 1 | hasaki
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | nizwa
# Processing Record 33 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 1 | kaitangata
# Processing Record 35 of Set 1 | batticaloa
# Processing Record 36 of Set 1 | vila
# Processing Record 37 of Set 1 | ormara
# Processing Record 38 of Set 1 | asau
# Processing Record 39 of Set 1 | tres arroyos
# Processing Record 40 of Set 1 | erenhot
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | zupanja
# Processing Record 43 of Set 1 | sistranda
# Processing Record 44 of Set 1 | vardo
# Processing Record 45 of Set 1 | ketchikan
# Processing Record 46 of Set 1 | victoria
# Processing Record 47 of Set 1 | arman
# Processing Record 48 of Set 1 | te anau
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | mar del plata
# Processing Record 1 of Set 2 | faanui
# Processing Record 2 of Set 2 | butaritari
# Processing Record 3 of Set 2 | sitka
# Processing Record 4 of Set 2 | mairi
# Processing Record 5 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 2 | tuatapere
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | puerto ayora
# Processing Record 9 of Set 2 | cidreira
# Processing Record 10 of Set 2 | praia da vitoria
# Processing Record 11 of Set 2 | georgetown
# Processing Record 12 of Set 2 | mitzic
# Processing Record 13 of Set 2 | hagere selam
# Processing Record 14 of Set 2 | trinidad
# Processing Record 15 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | vila velha
# Processing Record 19 of Set 2 | longyearbyen
# Processing Record 20 of Set 2 | severo-kurilsk
# Processing Record 21 of Set 2 | albany
# Processing Record 22 of Set 2 | melilla
# Processing Record 23 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 2 | lata
# Processing Record 25 of Set 2 | barberton
# Processing Record 26 of Set 2 | mayya
# Processing Record 27 of Set 2 | tommot
# Processing Record 28 of Set 2 | mgachi
# Processing Record 29 of Set 2 | cape town
# Processing Record 30 of Set 2 | la ronge
# Processing Record 31 of Set 2 | san borja
# Processing Record 32 of Set 2 | henties bay
# Processing Record 33 of Set 2 | dikson
# Processing Record 34 of Set 2 | kapaa
# Processing Record 35 of Set 2 | luderitz
# Processing Record 36 of Set 2 | yenagoa
# Processing Record 37 of Set 2 | bambous virieux
# Processing Record 38 of Set 2 | namatanai
# Processing Record 39 of Set 2 | husavik
# Processing Record 40 of Set 2 | hobart
# Processing Record 41 of Set 2 | punta arenas
# Processing Record 42 of Set 2 | tadine
# Processing Record 43 of Set 2 | toora-khem
# Processing Record 44 of Set 2 | seoul
# Processing Record 45 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 2 | saint-francois
# Processing Record 47 of Set 2 | saskylakh
# Processing Record 48 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 2 | amahai
# Processing Record 50 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 3 | ustyuzhna
# Processing Record 2 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 3 | chernyshevskiy
# Processing Record 4 of Set 3 | hofn
# Processing Record 5 of Set 3 | senanga
# Processing Record 6 of Set 3 | baghdad
# Processing Record 7 of Set 3 | asheboro
# Processing Record 8 of Set 3 | dingle
# Processing Record 9 of Set 3 | santiago
# Processing Record 10 of Set 3 | vila franca do campo
# Processing Record 11 of Set 3 | nago
# Processing Record 12 of Set 3 | qaanaaq
# Processing Record 13 of Set 3 | pemangkat
# Processing Record 14 of Set 3 | cherskiy
# Processing Record 15 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 16 of Set 3 | aksarka
# Processing Record 17 of Set 3 | krasnoselkup
# Processing Record 18 of Set 3 | tutoia
# Processing Record 19 of Set 3 | gombong
# Processing Record 20 of Set 3 | puerto el triunfo
# Processing Record 21 of Set 3 | tuktoyaktuk
# Processing Record 22 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 3 | kulhudhuffushi
# Processing Record 24 of Set 3 | cap malheureux
# Processing Record 25 of Set 3 | sao filipe
# Processing Record 26 of Set 3 | herat
# Processing Record 27 of Set 3 | lianzhou
# Processing Record 28 of Set 3 | seddon
# Processing Record 29 of Set 3 | lasa
# Processing Record 30 of Set 3 | shelton
# Processing Record 31 of Set 3 | olafsvik
# Processing Record 32 of Set 3 | necochea
# Processing Record 33 of Set 3 | veraval
# Processing Record 34 of Set 3 | nanortalik
# Processing Record 35 of Set 3 | bela
# Processing Record 36 of Set 3 | palmer
# Processing Record 37 of Set 3 | sompeta
# Processing Record 38 of Set 3 | codrington
# Processing Record 39 of Set 3 | plainview
# Processing Record 40 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 41 of Set 3 | byron bay
# Processing Record 42 of Set 3 | bonthe
# Processing Record 43 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 3 | port alfred
# Processing Record 45 of Set 3 | guerrero negro
# Processing Record 46 of Set 3 | urucui
# Processing Record 47 of Set 3 | tsienyane
# City not found. Skipping...
# Processing Record 48 of Set 3 | buchanan
# Processing Record 49 of Set 3 | coleraine
# Processing Record 50 of Set 3 | kindu
# Processing Record 1 of Set 4 | ushuaia
# Processing Record 2 of Set 4 | shingu
# Processing Record 3 of Set 4 | charters towers
# Processing Record 4 of Set 4 | lorengau
# Processing Record 5 of Set 4 | solnechnyy
# Processing Record 6 of Set 4 | pontes e lacerda
# Processing Record 7 of Set 4 | thyolo
# Processing Record 8 of Set 4 | pevek
# Processing Record 9 of Set 4 | bolonchen
# City not found. Skipping...
# Processing Record 10 of Set 4 | taoyuan
# Processing Record 11 of Set 4 | waipawa
# Processing Record 12 of Set 4 | margate
# Processing Record 13 of Set 4 | beyneu
# Processing Record 14 of Set 4 | laguna
# Processing Record 15 of Set 4 | baft
# Processing Record 16 of Set 4 | kunjah
# Processing Record 17 of Set 4 | airai
# Processing Record 18 of Set 4 | misratah
# Processing Record 19 of Set 4 | komsomolskiy
# Processing Record 20 of Set 4 | brae
# Processing Record 21 of Set 4 | hithadhoo
# Processing Record 22 of Set 4 | la primavera
# Processing Record 23 of Set 4 | port lincoln
# Processing Record 24 of Set 4 | tiksi
# Processing Record 25 of Set 4 | ocean springs
# Processing Record 26 of Set 4 | boa vista
# Processing Record 27 of Set 4 | hirara
# Processing Record 28 of Set 4 | coquimbo
# Processing Record 29 of Set 4 | urumqi
# Processing Record 30 of Set 4 | vestmannaeyjar
# Processing Record 31 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 4 | cape canaveral
# Processing Record 33 of Set 4 | thompson
# Processing Record 34 of Set 4 | llangefni
# Processing Record 35 of Set 4 | iowa city
# Processing Record 36 of Set 4 | port elizabeth
# Processing Record 37 of Set 4 | bandarbeyla
# Processing Record 38 of Set 4 | tilichiki
# Processing Record 39 of Set 4 | harlingen
# Processing Record 40 of Set 4 | itagiba
# Processing Record 41 of Set 4 | cap-aux-meules
# Processing Record 42 of Set 4 | gamba
# Processing Record 43 of Set 4 | palora
# Processing Record 44 of Set 4 | pisco
# Processing Record 45 of Set 4 | goundam
# Processing Record 46 of Set 4 | chokurdakh
# Processing Record 47 of Set 4 | fazilka
# Processing Record 48 of Set 4 | kendari
# Processing Record 49 of Set 4 | alyangula
# Processing Record 50 of Set 4 | ucluelet
# Processing Record 1 of Set 5 | portree
# Processing Record 2 of Set 5 | moerai
# Processing Record 3 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 4 of Set 5 | poum
# Processing Record 5 of Set 5 | galle
# Processing Record 6 of Set 5 | port hardy
# Processing Record 7 of Set 5 | matara
# Processing Record 8 of Set 5 | saint-pierre
# Processing Record 9 of Set 5 | kutum
# Processing Record 10 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 5 | gorom-gorom
# Processing Record 12 of Set 5 | camana
# Processing Record 13 of Set 5 | warrnambool
# Processing Record 14 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 5 | anadyr
# Processing Record 16 of Set 5 | vostok
# Processing Record 17 of Set 5 | lebu
# Processing Record 18 of Set 5 | soyo
# Processing Record 19 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 20 of Set 5 | shenjiamen
# Processing Record 21 of Set 5 | narasannapeta
# Processing Record 22 of Set 5 | garden city
# Processing Record 23 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 24 of Set 5 | leningradskiy
# Processing Record 25 of Set 5 | videira
# Processing Record 26 of Set 5 | mount isa
# Processing Record 27 of Set 5 | komatipoort
# Processing Record 28 of Set 5 | east london
# Processing Record 29 of Set 5 | flinders
# Processing Record 30 of Set 5 | ancud
# Processing Record 31 of Set 5 | binga
# Processing Record 32 of Set 5 | ribeira grande
# Processing Record 33 of Set 5 | turukhansk
# Processing Record 34 of Set 5 | zhigansk
# Processing Record 35 of Set 5 | nouadhibou
# Processing Record 36 of Set 5 | siyabuswa
# Processing Record 37 of Set 5 | zapolyarnyy
# Processing Record 38 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 39 of Set 5 | bethel
# Processing Record 40 of Set 5 | ochamchira
# Processing Record 41 of Set 5 | cam pha
# City not found. Skipping...
# Processing Record 42 of Set 5 | ape
# Processing Record 43 of Set 5 | jiangyou
# Processing Record 44 of Set 5 | isangel
# Processing Record 45 of Set 5 | talaya
# Processing Record 46 of Set 5 | teguldet
# Processing Record 47 of Set 5 | robertsport
# Processing Record 48 of Set 5 | hanko
# Processing Record 49 of Set 5 | smithers
# Processing Record 50 of Set 5 | waingapu
# Processing Record 1 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 6 | gat
# Processing Record 3 of Set 6 | poykovskiy
# Processing Record 4 of Set 6 | ulladulla
# Processing Record 5 of Set 6 | upernavik
# Processing Record 6 of Set 6 | tupik
# Processing Record 7 of Set 6 | havelock
# Processing Record 8 of Set 6 | bakchar
# Processing Record 9 of Set 6 | new norfolk
# Processing Record 10 of Set 6 | talnakh
# Processing Record 11 of Set 6 | fortuna
# Processing Record 12 of Set 6 | djambala
# Processing Record 13 of Set 6 | kungurtug
# Processing Record 14 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 6 | ankazoabo
# Processing Record 17 of Set 6 | souillac
# Processing Record 18 of Set 6 | saint-georges
# Processing Record 19 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 6 | torbay
# Processing Record 21 of Set 6 | gasa
# Processing Record 22 of Set 6 | ahipara
# Processing Record 23 of Set 6 | inirida
# Processing Record 24 of Set 6 | balkhash
# Processing Record 25 of Set 6 | young
# Processing Record 26 of Set 6 | marzuq
# Processing Record 27 of Set 6 | ilulissat
# Processing Record 28 of Set 6 | port macquarie
# Processing Record 29 of Set 6 | iracoubo
# Processing Record 30 of Set 6 | clyde river
# Processing Record 31 of Set 6 | udachnyy
# Processing Record 32 of Set 6 | peniche
# Processing Record 33 of Set 6 | dunedin
# Processing Record 34 of Set 6 | kavaratti
# Processing Record 35 of Set 6 | puerto del rosario
# Processing Record 36 of Set 6 | kaduqli
# Processing Record 37 of Set 6 | sarangani
# Processing Record 38 of Set 6 | gambo
# Processing Record 39 of Set 6 | los llanos de aridane
# Processing Record 40 of Set 6 | provideniya
# Processing Record 41 of Set 6 | wanning
# Processing Record 42 of Set 6 | miraflores
# Processing Record 43 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 44 of Set 6 | sorland
# Processing Record 45 of Set 6 | mandurah
# Processing Record 46 of Set 6 | milingimbi
# City not found. Skipping...
# Processing Record 47 of Set 6 | shimoda
# Processing Record 48 of Set 6 | rawson
# Processing Record 49 of Set 6 | kargopol
# Processing Record 50 of Set 6 | rio gallegos
# Processing Record 1 of Set 7 | nantucket
# Processing Record 2 of Set 7 | sovetskiy
# Processing Record 3 of Set 7 | san cristobal
# Processing Record 4 of Set 7 | grindavik
# Processing Record 5 of Set 7 | lavrentiya
# Processing Record 6 of Set 7 | yumen
# Processing Record 7 of Set 7 | knysna
# Processing Record 8 of Set 7 | umm ruwabah
# City not found. Skipping...
# Processing Record 9 of Set 7 | saint george
# Processing Record 10 of Set 7 | angra
# City not found. Skipping...
# Processing Record 11 of Set 7 | northam
# Processing Record 12 of Set 7 | leninskoye
# Processing Record 13 of Set 7 | high prairie
# Processing Record 14 of Set 7 | felanitx
# Processing Record 15 of Set 7 | chegdomyn
# Processing Record 16 of Set 7 | urucara
# Processing Record 17 of Set 7 | bathsheba
# Processing Record 18 of Set 7 | otane
# Processing Record 19 of Set 7 | kota bahru
# Processing Record 20 of Set 7 | nikolskoye
# Processing Record 21 of Set 7 | ponta do sol
# Processing Record 22 of Set 7 | khandyga
# Processing Record 23 of Set 7 | nipawin
# Processing Record 24 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 25 of Set 7 | gutierrez zamora
# Processing Record 26 of Set 7 | talcahuano
# Processing Record 27 of Set 7 | itoman
# Processing Record 28 of Set 7 | aklavik
# Processing Record 29 of Set 7 | half moon bay
# Processing Record 30 of Set 7 | cayenne
# Processing Record 31 of Set 7 | etchojoa
# Processing Record 32 of Set 7 | kochki
# Processing Record 33 of Set 7 | broome
# Processing Record 34 of Set 7 | beloha
# Processing Record 35 of Set 7 | bengkulu
# Processing Record 36 of Set 7 | olenino
# Processing Record 37 of Set 7 | santa vitoria do palmar
# Processing Record 38 of Set 7 | skjervoy
# Processing Record 39 of Set 7 | maltahohe
# Processing Record 40 of Set 7 | buala
# Processing Record 41 of Set 7 | kieta
# Processing Record 42 of Set 7 | karratha
# Processing Record 43 of Set 7 | tura
# Processing Record 44 of Set 7 | durban
# Processing Record 45 of Set 7 | bilibino
# Processing Record 46 of Set 7 | vrangel
# Processing Record 47 of Set 7 | calabozo
# Processing Record 48 of Set 7 | caravelas
# Processing Record 49 of Set 7 | villamontes
# Processing Record 50 of Set 7 | amuntai
# Processing Record 1 of Set 8 | umaria
# Processing Record 2 of Set 8 | acarau
# Processing Record 3 of Set 8 | saint-leu
# Processing Record 4 of Set 8 | iralaya
# Processing Record 5 of Set 8 | luanda
# Processing Record 6 of Set 8 | zholymbet
# Processing Record 7 of Set 8 | el dovio
# Processing Record 8 of Set 8 | lazaro cardenas
# Processing Record 9 of Set 8 | srednekolymsk
# Processing Record 10 of Set 8 | olinda
# Processing Record 11 of Set 8 | tanete
# Processing Record 12 of Set 8 | shiyan
# Processing Record 13 of Set 8 | port augusta
# Processing Record 14 of Set 8 | fountain hills
# Processing Record 15 of Set 8 | bonito
# Processing Record 16 of Set 8 | saldanha
# Processing Record 17 of Set 8 | banepa
# Processing Record 18 of Set 8 | mandalgovi
# Processing Record 19 of Set 8 | blairmore
# Processing Record 20 of Set 8 | bahir dar
# Processing Record 21 of Set 8 | praxedis guerrero
# Processing Record 22 of Set 8 | yellowknife
# Processing Record 23 of Set 8 | chinsali
# Processing Record 24 of Set 8 | tateyama
# Processing Record 25 of Set 8 | tortoli
# Processing Record 26 of Set 8 | flin flon
# Processing Record 27 of Set 8 | marquette
# Processing Record 28 of Set 8 | tazovskiy
# Processing Record 29 of Set 8 | nakhodka
# Processing Record 30 of Set 8 | gueret
# Processing Record 31 of Set 8 | songjianghe
# Processing Record 32 of Set 8 | ostrovnoy
# Processing Record 33 of Set 8 | tocopilla
# Processing Record 34 of Set 8 | pastavy
# Processing Record 35 of Set 8 | abu dhabi
# Processing Record 36 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 8 | rockhampton
# Processing Record 38 of Set 8 | ixtapa
# Processing Record 39 of Set 8 | san patricio
# Processing Record 40 of Set 8 | carroll
# Processing Record 41 of Set 8 | munster
# Processing Record 42 of Set 8 | aswan
# Processing Record 43 of Set 8 | sinjar
# Processing Record 44 of Set 8 | kulykivka
# Processing Record 45 of Set 8 | vao
# Processing Record 46 of Set 8 | dudley
# Processing Record 47 of Set 8 | saint-augustin
# Processing Record 48 of Set 8 | nebolchi
# Processing Record 49 of Set 8 | payakumbuh
# Processing Record 50 of Set 8 | port blair
# Processing Record 1 of Set 9 | sorokino
# Processing Record 2 of Set 9 | nanyang
# Processing Record 3 of Set 9 | abu samrah
# Processing Record 4 of Set 9 | unye
# City not found. Skipping...
# Processing Record 5 of Set 9 | omboue
# Processing Record 6 of Set 9 | tacna
# Processing Record 7 of Set 9 | honningsvag
# Processing Record 8 of Set 9 | rudnogorsk
# Processing Record 9 of Set 9 | madang
# Processing Record 10 of Set 9 | ocampo
# Processing Record 11 of Set 9 | meulaboh
# Processing Record 12 of Set 9 | monrovia
# Processing Record 13 of Set 9 | chahal
# Processing Record 14 of Set 9 | churapcha
# Processing Record 15 of Set 9 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 16 of Set 9 | adrar
# Processing Record 17 of Set 9 | morondava
# Processing Record 18 of Set 9 | fairbanks
# Processing Record 19 of Set 9 | ambilobe
# Processing Record 20 of Set 9 | pangnirtung
# Processing Record 21 of Set 9 | salekhard
# Processing Record 22 of Set 9 | yelizovo
# Processing Record 23 of Set 9 | touros
# Processing Record 24 of Set 9 | saint-chamond
# Processing Record 25 of Set 9 | tasiilaq
# Processing Record 26 of Set 9 | saravan
# Processing Record 27 of Set 9 | kokkola
# Processing Record 28 of Set 9 | dong hoi
# Processing Record 29 of Set 9 | kavieng
# Processing Record 30 of Set 9 | cochrane
# Processing Record 31 of Set 9 | coihaique
# Processing Record 32 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 9 | iberia
# Processing Record 34 of Set 9 | katsuura
# Processing Record 35 of Set 9 | tiruvottiyur
# City not found. Skipping...
# Processing Record 36 of Set 9 | hobyo
# Processing Record 37 of Set 9 | valley city
# Processing Record 38 of Set 9 | adre
# Processing Record 39 of Set 9 | samarai
# Processing Record 40 of Set 9 | mehamn
# Processing Record 41 of Set 9 | gouyave
# Processing Record 42 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 44 of Set 9 | gravdal
# Processing Record 45 of Set 9 | portland
# Processing Record 46 of Set 9 | malvern
# Processing Record 47 of Set 9 | oranjemund
# Processing Record 48 of Set 9 | geraldton
# Processing Record 49 of Set 9 | bubaque
# Processing Record 50 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 1 of Set 10 | tiznit
# Processing Record 2 of Set 10 | evanston
# Processing Record 3 of Set 10 | sergeyevka
# Processing Record 4 of Set 10 | avarua
# Processing Record 5 of Set 10 | bintulu
# Processing Record 6 of Set 10 | ocos
# Processing Record 7 of Set 10 | naze
# Processing Record 8 of Set 10 | okitipupa
# Processing Record 9 of Set 10 | bambanglipuro
# Processing Record 10 of Set 10 | jamnah
# City not found. Skipping...
# Processing Record 11 of Set 10 | sandakan
# Processing Record 12 of Set 10 | benghazi
# Processing Record 13 of Set 10 | ayagoz
# Processing Record 14 of Set 10 | thinadhoo
# Processing Record 15 of Set 10 | noumea
# Processing Record 16 of Set 10 | ierapetra
# Processing Record 17 of Set 10 | khanpur
# Processing Record 18 of Set 10 | atar
# Processing Record 19 of Set 10 | saint anthony
# Processing Record 20 of Set 10 | yerbogachen
# Processing Record 21 of Set 10 | auray
# Processing Record 22 of Set 10 | quatre cocos
# Processing Record 23 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 24 of Set 10 | filingue
# Processing Record 25 of Set 10 | vuktyl
# Processing Record 26 of Set 10 | midland
# Processing Record 27 of Set 10 | aykhal
# Processing Record 28 of Set 10 | mudanjiang
# Processing Record 29 of Set 10 | pergamino
# Processing Record 30 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 31 of Set 10 | viedma
# Processing Record 32 of Set 10 | ipora
# Processing Record 33 of Set 10 | el obraje
# Processing Record 34 of Set 10 | george
# Processing Record 35 of Set 10 | nampula
# Processing Record 36 of Set 10 | nerchinskiy zavod
# Processing Record 37 of Set 10 | biharamulo
# Processing Record 38 of Set 10 | maryville
# Processing Record 39 of Set 10 | maniitsoq
# Processing Record 40 of Set 10 | hambantota
# Processing Record 41 of Set 10 | kruisfontein
# Processing Record 42 of Set 10 | korla
# Processing Record 43 of Set 10 | lembeni
# Processing Record 44 of Set 10 | ossora
# Processing Record 45 of Set 10 | constitucion
# Processing Record 46 of Set 10 | billings
# Processing Record 47 of Set 10 | fallon
# Processing Record 48 of Set 10 | salalah
# Processing Record 49 of Set 10 | plettenberg bay
# Processing Record 50 of Set 10 | teya
# Processing Record 1 of Set 11 | jha jha
# Processing Record 2 of Set 11 | nagato
# Processing Record 3 of Set 11 | kijang
# Processing Record 4 of Set 11 | pristina
# Processing Record 5 of Set 11 | luohe
# Processing Record 6 of Set 11 | luganville
# Processing Record 7 of Set 11 | agucadoura
# Processing Record 8 of Set 11 | itarema
# Processing Record 9 of Set 11 | xuddur
# Processing Record 10 of Set 11 | rurrenabaque
# Processing Record 11 of Set 11 | imbituba
# Processing Record 12 of Set 11 | san vicente
# Processing Record 13 of Set 11 | envira
# Processing Record 14 of Set 11 | mayumba
# Processing Record 15 of Set 11 | kanchanaburi
# Processing Record 16 of Set 11 | derzhavinsk
# Processing Record 17 of Set 11 | juba
# Processing Record 18 of Set 11 | roald
# Processing Record 19 of Set 11 | iranshahr
# Processing Record 20 of Set 11 | skibbereen
# Processing Record 21 of Set 11 | lagoa
# Processing Record 22 of Set 11 | breda
# Processing Record 23 of Set 11 | kukushtan
# Processing Record 24 of Set 11 | verkhnyaya toyma
# Processing Record 25 of Set 11 | shellbrook
# Processing Record 26 of Set 11 | caruray
# Processing Record 27 of Set 11 | banes
# Processing Record 28 of Set 11 | rincon
# Processing Record 29 of Set 11 | andenes
# Processing Record 30 of Set 11 | puerto maldonado
# Processing Record 31 of Set 11 | ajdabiya
# Processing Record 32 of Set 11 | longkou
# Processing Record 33 of Set 11 | villa carlos paz
# Processing Record 34 of Set 11 | laela
# Processing Record 35 of Set 11 | corinto
# Processing Record 36 of Set 11 | lompoc
# Processing Record 37 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 38 of Set 11 | tarko-sale
# Processing Record 39 of Set 11 | galesong
# Processing Record 40 of Set 11 | deputatskiy
# Processing Record 41 of Set 11 | gorontalo
# Processing Record 42 of Set 11 | raudeberg
# Processing Record 43 of Set 11 | cortez
# Processing Record 44 of Set 11 | treinta y tres
# Processing Record 45 of Set 11 | puerto leguizamo
# Processing Record 46 of Set 11 | mago
# Processing Record 47 of Set 11 | umm lajj
# Processing Record 48 of Set 11 | bairiki
# Processing Record 49 of Set 11 | goderich
# Processing Record 50 of Set 11 | mount gambier
# Processing Record 1 of Set 12 | leshukonskoye
# Processing Record 2 of Set 12 | marrakesh
# Processing Record 3 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 12 | jega
# Processing Record 5 of Set 12 | masallatah
# Processing Record 6 of Set 12 | araouane
# Processing Record 7 of Set 12 | zhezkazgan
# Processing Record 8 of Set 12 | hailey
# Processing Record 9 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 12 | esperance
# Processing Record 11 of Set 12 | padang
# Processing Record 12 of Set 12 | taltal
# Processing Record 13 of Set 12 | sola
# Processing Record 14 of Set 12 | hauterive
# Processing Record 15 of Set 12 | kovdor
# Processing Record 16 of Set 12 | harper
# Processing Record 17 of Set 12 | nyrob
# Processing Record 18 of Set 12 | sfantu gheorghe
# Processing Record 19 of Set 12 | manta
# Processing Record 20 of Set 12 | muros
# Processing Record 21 of Set 12 | tecoanapa
# Processing Record 22 of Set 12 | tonekabon
# Processing Record 23 of Set 12 | amapa
# Processing Record 24 of Set 12 | sarahan
# Processing Record 25 of Set 12 | cirebon
# Processing Record 26 of Set 12 | nizhniy kuranakh
# Processing Record 27 of Set 12 | burica
# City not found. Skipping...
# Processing Record 28 of Set 12 | goroka
# Processing Record 29 of Set 12 | kupang
# Processing Record 30 of Set 12 | yabelo
# Processing Record 31 of Set 12 | krasnorechenskiy
# Processing Record 32 of Set 12 | alice springs
# Processing Record 33 of Set 12 | chichihualco
# Processing Record 34 of Set 12 | kloulklubed
# Processing Record 35 of Set 12 | mareeba
# Processing Record 36 of Set 12 | mokrousovo
# Processing Record 37 of Set 12 | de land
# Processing Record 38 of Set 12 | muhos
# Processing Record 39 of Set 12 | yining
# Processing Record 40 of Set 12 | tomatlan
# Processing Record 41 of Set 12 | calbuco
# Processing Record 42 of Set 12 | issia
# Processing Record 43 of Set 12 | grand gaube
# Processing Record 44 of Set 12 | tuy hoa
# Processing Record 45 of Set 12 | tamandare
# Processing Record 46 of Set 12 | kousseri
# Processing Record 47 of Set 12 | orgun
# City not found. Skipping...
# Processing Record 48 of Set 12 | san policarpo
# Processing Record 49 of Set 12 | mitsamiouli
# Processing Record 50 of Set 12 | zharkent
# Processing Record 1 of Set 13 | brownwood
# Processing Record 2 of Set 13 | oktyabrskiy
# Processing Record 3 of Set 13 | bagdarin
# Processing Record 4 of Set 13 | salinopolis
# Processing Record 5 of Set 13 | dinsor
# City not found. Skipping...
# Processing Record 6 of Set 13 | kapoeta
# Processing Record 7 of Set 13 | yurimaguas
# Processing Record 8 of Set 13 | saltillo
# Processing Record 9 of Set 13 | kandrian
# Processing Record 10 of Set 13 | bolshiye kaybitsy
# City not found. Skipping...
# Processing Record 11 of Set 13 | san quintin
# Processing Record 12 of Set 13 | san rafael
# Processing Record 13 of Set 13 | barcea
# Processing Record 14 of Set 13 | haines junction
# Processing Record 15 of Set 13 | warrington
# Processing Record 16 of Set 13 | teguise
# Processing Record 17 of Set 13 | okha
# Processing Record 18 of Set 13 | jalu
# Processing Record 19 of Set 13 | rio grande
# Processing Record 20 of Set 13 | dickinson
# Processing Record 21 of Set 13 | mayskiy
# Processing Record 22 of Set 13 | linxia
# Processing Record 23 of Set 13 | qinhuangdao
# Processing Record 24 of Set 13 | yulara
# Processing Record 25 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 26 of Set 13 | columbus
# Processing Record 27 of Set 13 | bejar
# Processing Record 28 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 29 of Set 13 | khatanga
# Processing Record 30 of Set 13 | vangaindrano
# Processing Record 31 of Set 13 | takoradi
# Processing Record 32 of Set 13 | fayetteville
# Processing Record 33 of Set 13 | champerico
# Processing Record 34 of Set 13 | bukama
# Processing Record 35 of Set 13 | moron
# Processing Record 36 of Set 13 | road town
# Processing Record 37 of Set 13 | healesville
# Processing Record 38 of Set 13 | biloela
# Processing Record 39 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 40 of Set 13 | mananjary
# Processing Record 41 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 13 | cumpas
# Processing Record 43 of Set 13 | springbok
# Processing Record 44 of Set 13 | burila mare
# Processing Record 45 of Set 13 | glubokoe
# City not found. Skipping...
# Processing Record 46 of Set 13 | agogo
# Processing Record 47 of Set 13 | zhangye
# Processing Record 48 of Set 13 | ponta delgada
# Processing Record 49 of Set 13 | nurlat
# Processing Record 50 of Set 13 | neuquen
# Processing Record 1 of Set 14 | akyab
# Processing Record 2 of Set 14 | aquiraz
# Processing Record 3 of Set 14 | hovd
# Processing Record 4 of Set 14 | porto novo
# Processing Record 5 of Set 14 | yaviza
# Processing Record 6 of Set 14 | zhanaozen
# Processing Record 7 of Set 14 | alofi
# Processing Record 8 of Set 14 | cururupu
# Processing Record 9 of Set 14 | caraballeda
# Processing Record 10 of Set 14 | comodoro rivadavia
# Processing Record 11 of Set 14 | newport
# Processing Record 12 of Set 14 | kralendijk
# Processing Record 13 of Set 14 | mercedes
# Processing Record 14 of Set 14 | minab
# Processing Record 15 of Set 14 | buta
# Processing Record 16 of Set 14 | oshnaviyeh
# Processing Record 17 of Set 14 | bowen
# Processing Record 18 of Set 14 | berlevag
# Processing Record 19 of Set 14 | breyten
# Processing Record 20 of Set 14 | laibin
# Processing Record 21 of Set 14 | utuado
# Processing Record 22 of Set 14 | picota
# Processing Record 23 of Set 14 | constantine
# Processing Record 24 of Set 14 | ko samui
# Processing Record 25 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 14 | camacupa
# Processing Record 27 of Set 14 | chalon-sur-saone
# Processing Record 28 of Set 14 | cockburn town
# Processing Record 29 of Set 14 | marienburg
# Processing Record 30 of Set 14 | mabay
# Processing Record 31 of Set 14 | shelburne
# Processing Record 32 of Set 14 | sao sebastiao
# Processing Record 33 of Set 14 | garissa
# Processing Record 34 of Set 14 | kirakira
# Processing Record 35 of Set 14 | bima
# Processing Record 36 of Set 14 | camocim
# Processing Record 37 of Set 14 | lodja
# Processing Record 38 of Set 14 | burns lake
# Processing Record 39 of Set 14 | bria
# Processing Record 40 of Set 14 | dubrovnik
# Processing Record 41 of Set 14 | taoudenni
# Processing Record 42 of Set 14 | revda
# Processing Record 43 of Set 14 | mayo
# Processing Record 44 of Set 14 | fort nelson
# Processing Record 45 of Set 14 | varberg
# Processing Record 46 of Set 14 | hamilton
# Processing Record 47 of Set 14 | muncar
# Processing Record 48 of Set 14 | kadaya
# Processing Record 49 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 50 of Set 14 | beringovskiy
# Processing Record 1 of Set 15 | micheweni
# Processing Record 2 of Set 15 | phumi samraong
# City not found. Skipping...
# Processing Record 3 of Set 15 | pirovskoye
# Processing Record 4 of Set 15 | mayfield
# Processing Record 5 of Set 15 | klaksvik
# Processing Record 6 of Set 15 | nador
# Processing Record 7 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 15 | kayes
# Processing Record 9 of Set 15 | troitsko-pechorsk
# Processing Record 10 of Set 15 | oriximina
# Processing Record 11 of Set 15 | kawambwa
# Processing Record 12 of Set 15 | sinnamary
# Processing Record 13 of Set 15 | iqaluit
# Processing Record 14 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 15 of Set 15 | steinbach
# Processing Record 16 of Set 15 | kattivakkam
# Processing Record 17 of Set 15 | belmonte
# Processing Record 18 of Set 15 | suoyarvi
# Processing Record 19 of Set 15 | nuuk
# Processing Record 20 of Set 15 | beruwala
# Processing Record 21 of Set 15 | gallup
# Processing Record 22 of Set 15 | elko
# Processing Record 23 of Set 15 | parrsboro
# Processing Record 24 of Set 15 | riyadh
# Processing Record 25 of Set 15 | belyy yar
# Processing Record 26 of Set 15 | oga
# Processing Record 27 of Set 15 | guaruja
# Processing Record 28 of Set 15 | korcula
# Processing Record 29 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 30 of Set 15 | bongandanga
# Processing Record 31 of Set 15 | pemba
# Processing Record 32 of Set 15 | eureka
# Processing Record 33 of Set 15 | maldonado
# Processing Record 34 of Set 15 | praia
# Processing Record 35 of Set 15 | uralskiy
# City not found. Skipping...
# Processing Record 36 of Set 15 | oksfjord
# Processing Record 37 of Set 15 | mustasaari
# Processing Record 38 of Set 15 | koster
# Processing Record 39 of Set 15 | darab
# Processing Record 40 of Set 15 | madhoganj
# Processing Record 41 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 42 of Set 15 | tepulco
# Processing Record 43 of Set 15 | natalinsk
# Processing Record 44 of Set 15 | barillas
# Processing Record 45 of Set 15 | gornopravdinsk
# Processing Record 46 of Set 15 | benjamin aceval
# Processing Record 47 of Set 15 | aberdeen
# Processing Record 48 of Set 15 | stettler
# Processing Record 49 of Set 15 | lufilufi
# Processing Record 50 of Set 15 | port keats
# Processing Record 1 of Set 16 | hami
# Processing Record 2 of Set 16 | tamayo
# Processing Record 3 of Set 16 | panaba
# Processing Record 4 of Set 16 | koungou
# Processing Record 5 of Set 16 | nyurba
# Processing Record 6 of Set 16 | emerald
# Processing Record 7 of Set 16 | nhulunbuy
# Processing Record 8 of Set 16 | saint-denis
# Processing Record 9 of Set 16 | lipari
# Processing Record 10 of Set 16 | auki
# Processing Record 11 of Set 16 | fukue
# Processing Record 12 of Set 16 | port-gentil
# Processing Record 13 of Set 16 | ukiah
# Processing Record 14 of Set 16 | kaseda
# Processing Record 15 of Set 16 | bagotville
# Processing Record 16 of Set 16 | carangola
# Processing Record 17 of Set 16 | darnah
# Processing Record 18 of Set 16 | puerto baquerizo moreno
# Processing Record 19 of Set 16 | la macarena
# Processing Record 20 of Set 16 | roma
# Processing Record 21 of Set 16 | dongsheng
# Processing Record 22 of Set 16 | phetchabun
# Processing Record 23 of Set 16 | kangaatsiaq
# Processing Record 24 of Set 16 | svetlaya
# Processing Record 25 of Set 16 | muzaffarabad
# Processing Record 26 of Set 16 | rolim de moura
# City not found. Skipping...
# Processing Record 27 of Set 16 | vestmanna
# Processing Record 28 of Set 16 | cuamba
# Processing Record 29 of Set 16 | am timan
# Processing Record 30 of Set 16 | faya
# Processing Record 31 of Set 16 | namibe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Add the data to a new DataFrame.
    #Before exporting your new DataFrame as a CSV file, take a moment to confirm that it looks similar to the image below:

#The new cities_data DataFrame summarizes the current weather description.

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Cabo San Lucas      MX  22.8909 -109.9124     96.51        48           1
# 1         College      US  64.8569 -147.8028     60.75        77          90
# 2          Barrow      US  71.2906 -156.7887     35.62        75          40
# 3       Carnarvon      AU -24.8667  113.6333     62.67        55          75
# 4          Atuona      PF  -9.8000 -139.0333     78.40        63          14
#
#    Wind Speed       Description
# 0       11.50         clear sky
# 1        5.75        light rain
# 2        8.05  scattered clouds
# 3       13.80     broken clouds
# 4       23.38        few clouds

# %%
#Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
